# %%
# %reset -f
import pandas as pd
import requests
import json

# %%
# API endpoints
url = 'https://fantasy.premierleague.com/api/bootstrap-static/'

# %%
response = requests.get(url)

if response.status_code == 200:
    print('The API request was successful.')
else:
    print(f'Error: The API request failed with status code {response.status_code}.')
# Out:
# The API request was successful.

# %%
pd.options.display.max_columns = 50
pd.options.display.max_rows = 100

# %%
response = requests.get(url)
players = response.json()['elements']

# %%
element_types = response.json()['element_types']
position_mapping = {}

for pos in element_types:
    position_mapping[pos['id']] = pos['singular_name']

# %%
player_info = []

for player in players:
    player_id = player['id']
    name = player['first_name'] + ' ' + player['second_name']
    position = position_mapping[player['element_type']]
    points = player['total_points']
    bonus = player['bonus']
    value = player['now_cost']/10
    minutes = player['minutes']
    ppg = player['points_per_game']  
    goals = player['goals_scored']
    xg = player['expected_goals']
    xg90 = player['expected_goals_per_90']
    assists = player['assists']
    xa = player['expected_assists']
    xa90 = player['expected_assists_per_90']
    cs = player['clean_sheets']
    goals_conc = player['goals_conceded']
    xgc = player['expected_goals_conceded']
    xgc90 = player['expected_goals_conceded_per_90']
    saves = player['saves']
    influence = player['influence']
    threat = player['threat']  
    creativity = player['creativity']
    transfers_in = player['transfers_in_event']
    transfers_out = player['transfers_out_event']
  
    player_info.append({
        'name': name,
        'pos': position[:1],
        'val': value,
        'mins': minutes,
        'pts': points,
        'pts-bns': int(points) - bonus,
        'ppg': ppg,
        'g': goals,
        'xg': float(xg),
        'xg90': xg90,
        'ass': assists,
        'xa': float(xa),
        'xa90': xa90,
        'cs': cs,
        'gc': goals_conc,
        'xgc': float(xgc),
        'xgc90': xgc90,
        'saves': saves,
        'influence': influence,
        'threat': threat,
        'creativity': creativity,
        'tra_in': transfers_in,
        'tra_out': transfers_out
    })
    
df = pd.DataFrame(player_info)

# %%
# Midfielders
mid = df.drop(columns=['cs', 'gc','saves','xgc','xgc90'])
mid.insert(6, 'xp', mid.assign(xp = mid['xa'] * 3 + mid['xg'] * 5)['xp'])
filtered_mid = mid[(mid['pos'] == 'M') & ((mid['xg90'] > 0.2) | (mid['xa90'] > 0.2)) & (mid['mins'] > 900) ]
sorted_mid = filtered_mid.sort_values(by='ppg', ascending=False)

styled_mid = sorted_mid.style.background_gradient(cmap='RdYlGn', subset=['g','ass','xa', 'xa90','xg', 'xg90']).format(precision=2)

styled_mid
# Out:
# <style type="text/css">
# #T_2b58e_row0_col8, #T_2b58e_row0_col9, #T_2b58e_row0_col10, #T_2b58e_row0_col11, #T_2b58e_row2_col12, #T_2b58e_row4_col13 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_2b58e_row0_col12 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_2b58e_row0_col13, #T_2b58e_row1_col13, #T_2b58e_row7_col13, #T_2b58e_row8_col10, #T_2b58e_row47_col13 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_2b58e_row1_col8, #T_2b58e_row2_col10 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_2b58e_row1_col9, #T_2b58e_row19_col13, #T_2b58e_row27_col13, #T_2b58e_row36_col13 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_2b58e_row1_col10, #T_2b58e_row22_col10, #T_2b58e_row24_col10, #T_2b58e_row33_col10, #T_2b58e_row38_col10, #T_2b58e_row42_col10 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T
{
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_2b58e_row9_col10 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_2b58e_row9_col11, #T_2b58e_row56_col11 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_2b58e_row9_col12 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# #T_2b58e_row10_col8, #T_2b58e_row10_col9, #T_2b58e_row14_col10, #T_2b58e_row16_col8, #T_2b58e_row22_col8, #T_2b58e_row25_col10, #T_2b58e_row32_col10 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_2b58e_row10_col10, #T_2b58e_row50_col10 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_2b58e_row10_col12, #T_2b58e_row15_col10, #T_2b58e_row16_col9 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_2b58e_row10_col13 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_2b58e_row11_col9, #T_2b58e_row21_col10, #T_2b58e_row39_col12, #T_2b58e_row48_col10 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_2b58e_row11_col11 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_2b58e_row11_col12 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_2b58e_row11_col13, #T_2b58e_row23_col13, #T_2b58e_row24_col13, #T_2b58e_row26_col12, #T_2b58e_row43_col13, #T_2b58e_row53_col13, #T_2b58e_row55_col13 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_2b58e_row12_col8, #T_2b58e_row16_col13, #T_2b58e_row46_col13, #T_2b58e_row54_col13 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_2b58e_row12_col9, #T_2b58e_row12_col10, #T_2b58e_row29_col8, #T_2b58e_row30_col13, #T_2b58e_row34_col11, #T_2b58e_row54_col12, #T_2b58e_row55_col8 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_2b58e_row12_col12 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_2b58e_row12_col13, #T_2b58e_row14_col13 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_2b58e_row13_col12 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_2b58e_row14_col8, #T_2b58e_row17_col8, #T_2b58e_row18_col10, #T_2b58e_row24_col8, #T_2b58e_row30_col8, #T_2b58e_row34_col8, #T_2b58e_row39_col10, #T_2b58e_row51_col10 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_2b58e_row14_col9, #T_2b58e_row44_col9, #T_2b58e_row45_col13 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# #T_2b58e_row14_col12 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_2b58e_row15_col9 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_2b58e_row15_col12 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_2b58e_row16_col12 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_2b58e_row17_col9, #T_2b58e_row46_col9 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_2b58e_row17_col10 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_2b58e_row17_col12 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_2b58e_row18_col9 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_2b58e_row18_col12, #T_2b58e_row40_col10 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_2b58e_row18_col13, #T_2b58e_row35_col13, #T_2b58e_row40_col13 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_2b58e_row19_col9 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_2b58e_row19_col10, #T_2b58e_row37_col10, #T_2b58e_row56_col10 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_2b58e_row19_col12, #T_2b58e_row21_col13 {
#   background-color: #daf08d;
#   col

# %%
# Forwards
forw = df.drop(columns=['cs', 'gc','saves','xgc','xgc90'])
forw.insert(6, 'xp', forw.assign(xp = forw['xa'] * 3 + forw['xg'] * 4)['xp'])
filtered_forw = forw[(forw['pos'] == 'F') & ((forw['xg90'] > 0.2) | (forw['xa90'] > 0.2)) & (forw['mins'] > 900) ]
sorted_forw = filtered_forw.sort_values(by='ppg', ascending=False)

styled_forw = sorted_forw.style.background_gradient(cmap='RdYlGn', subset=['g','ass','xa', 'xa90','xg', 'xg90']).format(precision=2)

styled_forw
# Out:
# <style type="text/css">
# #T_d0bea_row0_col8, #T_d0bea_row1_col9, #T_d0bea_row1_col10, #T_d0bea_row2_col11, #T_d0bea_row2_col12, #T_d0bea_row2_col13 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_d0bea_row0_col9 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_d0bea_row0_col10 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_d0bea_row0_col11, #T_d0bea_row4_col11, #T_d0bea_row6_col11, #T_d0bea_row12_col11 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_d0bea_row0_col12 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T
{
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_d0bea_row19_col9 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_d0bea_row19_col13 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_d0bea_row20_col10 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_d0bea_row20_col12 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_d0bea_row21_col9 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_d0bea_row21_col10 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# </style>
# <table id="T_d0bea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0bea_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_d0bea_level0_col1" class="col_heading level0 col1" >pos</th>
#       <th id="T_d0bea_level0_col2" class="col_heading level0 col2" >val</th>
#       <th id="T_d0bea_level0_col3" class="col_heading level0 col3" >mins</th>
#       <th id="T_d0bea_level0_col4" class="col_heading level0 col4" >pts</th>
#       <th id="T_d0bea_level0_col5" class="col_heading level0 col5" >pts-bns</th>
#       <th id="T_d0bea_level0_col6" class="col_heading level0 col6" >xp</th>
#       <th id="T_d0bea_level0_col7" class="col_heading level0 col7" >ppg</th>
#       <th id="T_d0bea_level0_col8" class="col_heading level0 col8" >g</th>
#       <th id="T_d0bea_level0_col9" class="col_heading level0 col9" >xg</th>
#       <th id="T_d0bea_level0_col10" class="col_heading level0 col10" >xg90</th>
#       <th id="T_d0bea_level0_col11" class="col_heading level0 col11" >ass</th>
#       <th id="T_d0bea_level0_col12" class="col_heading level0 col12" >xa</th>
#       <th id="T_d0bea_level0_col13" class="col_heading level0 col13" >xa90</th>
#       <th id="T_d0bea_level0_col14" class="col_heading level0 col14" >influence</th>
#       <th id="T_d0bea_level0_col15" class="col_heading level0 col15" >threat</th>
#       <th id="T_d0bea_level0_col16" class="col_heading level0 col16" >creativity</th>
#       <th id="T_d0bea_level0_col17" class="col_heading level0 col17" >tra_in</th>
#       <th id="T_d0bea_level0_col18" class="col_heading level0 col18" >tra_out</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0bea_level0_row0" c

# %%
# Defenders
dfn = df.drop(columns=['saves'])
dfn.insert(6, 'xp', dfn.assign(xp = dfn['xa'] * 3 + dfn['xg'] * 6 + dfn['cs'] * 4 )['xp'])
filtered_dfn = dfn[(dfn['pos'] == 'D') & (dfn['mins'] > 900)]
sorted_dfn = filtered_dfn.sort_values(by='ppg', ascending=False)

styled_dfn = sorted_dfn.style.background_gradient(cmap='RdYlGn', subset=['g','ass','xa', 'xa90','xg', 'xg90', 'cs']).format(precision=2)
styled_dfn = styled_dfn.background_gradient(cmap='RdYlGn_r', subset=['gc', 'xgc','xgc90']).format(precision=2)

styled_dfn
# Out:
# <style type="text/css">
# #T_535bc_row0_col8, #T_535bc_row3_col8, #T_535bc_row5_col11, #T_535bc_row8_col8, #T_535bc_row14_col11, #T_535bc_row15_col8, #T_535bc_row16_col8, #T_535bc_row21_col11, #T_535bc_row22_col11, #T_535bc_row33_col11 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_535bc_row0_col9, #T_535bc_row41_col17, #T_535bc_row44_col12, #T_535bc_row55_col16 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_535bc_row0_col10, #T_535bc_row0_col14, #T_535bc_row20_col15, #T_535bc_row23_col10, #T_535bc_row27_col14, #T_535bc_row31_col14, #T_535bc_row32_col14, #T_535bc_row44_col14, #T_535bc_row46_col14, #T_535bc_row48_col10, #T_535bc_row57_col15, #T_535bc_row78_col15 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T
{
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_535bc_row2_col13, #T_535bc_row19_col13, #T_535bc_row26_col13, #T_535bc_row34_col13, #T_535bc_row37_col13, #T_535bc_row45_col13, #T_535bc_row49_col13, #T_535bc_row52_col13, #T_535bc_row53_col13, #T_535bc_row63_col13, #T_535bc_row71_col12, #T_535bc_row71_col13, #T_535bc_row83_col13, #T_535bc_row89_col13, #T_535bc_row90_col13 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_535bc_row2_col15, #T_535bc_row14_col15, #T_535bc_row23_col15, #T_535bc_row29_col9, #T_535bc_row29_col15, #T_535bc_row34_col15, #T_535bc_row35_col9, #T_535bc_row35_col15, #T_535bc_row52_col15, #T_535bc_row82_col17 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_535bc_row2_col16, #T_535bc_row29_col12, #T_535bc_row30_col9 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_535bc_row2_col17, #T_535bc_row42_col17, #T_535bc_row57_col17, #T_535bc_row61_col17, #T_535bc_row63_col17 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_535bc_row3_col9, #T_535bc_row13_col15, #T_535bc_row15_col15, #T_535bc_row49_col15, #T_535bc_row51_col16, #T_535bc_row69_col17, #T_535bc_row81_col15 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_535bc_row3_col10, #T_535bc_row8_col14, #T_535bc_row12_col12, #T_535bc_row15_col10, #T_535bc_row18_col10, #T_535bc_row20_col14, #T_535bc_row21_col14, #T_535bc_row24_col10, #T_535bc_row25_col10, #T_535bc_row28_col10, #T_535bc_row30_col10, #T_535bc_row32_col16, #T_535bc_row33_col10, #T

# %%
# Goalies
gk = df.drop(columns=['xg','g','xg90','ass','xa','xa90','influence','threat','creativity'])
gk.insert(6, 'xp', gk.assign(xp = gk['cs'] * 4 + gk['xgc'] * -0.5 + gk['saves'] * 0.33 + gk['mins'] / 45)['xp'])
# gk.insert(7, 'diff', gk.assign(diff = gk['xp'] - gk['pts-bns'])['diff'])
filtered_gk = gk[(gk['pos'] == 'G') & (gk['mins'] > 180)]
sorted_gk = filtered_gk.sort_values(by='ppg', ascending=False)

styled_gk = sorted_gk.style.background_gradient(cmap='RdYlGn', subset=['cs', 'saves']).format(precision=2)
styled_gk = styled_gk.background_gradient(cmap='RdYlGn_r', subset=['gc', 'xgc','xgc90']).format(precision=2)

styled_gk
# Out:
# <style type="text/css">
# #T_dc180_row0_col8, #T_dc180_row18_col8, #T_dc180_row21_col8 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_dc180_row0_col9, #T_dc180_row1_col9, #T_dc180_row23_col10 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_dc180_row0_col10, #T_dc180_row1_col10 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_dc180_row0_col11 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_dc180_row0_col12 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_dc180_row1_col8, #T_dc180_row15_col8 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_dc180_row1_col11 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_dc180_row1_col12 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_dc180_row2_col8, #T_dc180_row4_col8, #T_dc180_row6_col8 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_dc180_row2_col9 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_dc180_row2_col10 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_dc180_row2_col11 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_dc180_row2_col12 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_dc180_row3_col8, #T_dc180_row14_col9 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_dc180_row3_col9, #T_dc180_row11_col9 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_dc180_row3_col10 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_dc180_row3_col11 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_dc180_row3_col12, #T_dc180_row5_col8, #T_dc180_row7_col9, #T_dc180_row8_col8, #T_dc180_row8_col11, #T_dc180_row22_col10 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_dc180_row4_col9 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_dc180_row4_col10 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_dc180_row4_col11 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_dc180_row4_col12, #T_dc180_row10_col8, #T_dc180_row12_col8, #T_dc180_row16_col8 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_dc180_row5_col9 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_dc180_row5_col10 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_dc180_row5_col11, #T_dc180_row9_col11 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_dc180_row5_col12 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_dc180_row6_col9, #T_dc180_row8_col9 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_dc180_row6_col10 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_dc180_row6_col11 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_dc180_row6_col12 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_dc180_row7_col8, #T_dc180_row14_col8, #T_dc180_row15_col9, #T_dc180_row19_col8, #T_dc180_row22_col8 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_dc180_row7_col10 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_dc180_row7_col11, #T_dc180_row14_col11 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_dc180_row7_col12, #T_dc180_row14_col12 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_dc180_row8_col10, #T_dc180_row10_col10 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_dc180_row8_col12, #T_dc180_row10_col11, #T_dc180_row12_col11 {
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_dc180_row9_col8 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_dc180_row9_col9, #T_dc180_row23_col12 {
#   background-color: #e0422f;
#   color: #f1f1f1;
# }
# #T_dc180_row9_col10 {
#   background-color: #c21c27;
#   color: #f1f1f1;
# }
# #T_dc180_row9_col12 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_dc180_row10_col9 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_dc180_row10_col12 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_dc180_row11_col8 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_dc180_row11_col10, #T_dc180_row15_col10, #T_dc180_row23_col11 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_dc180_row11_col11 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_dc180_row11_col12 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_dc180_row12_col9 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_dc180_row12_col10 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_dc180_row12_col12 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_dc180_row13_col8, #T_dc180_row17_col8 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_dc180_row13_col9 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# #T_dc180_row13_col10 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_dc180_row13_col11 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_dc180_row13_col12 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_dc180_row14_col10 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_dc180_row15_col11 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_dc180_row15_col12 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_dc180_row16_col9 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_dc180_row16_col10 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_dc180_row16_col11 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_dc180_row16_col12 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_dc180_row17_col9, #T_dc180_row17_col10, #T_dc180_row19_col11, #T_dc180_row22_col12, #T_dc180_row23_col8 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_dc180_row17_col11 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_dc180_row17_col12 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_dc180_row18_col9 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_dc180_row18_col10 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_dc180_row18_col11 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_dc180_row18_col12 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_dc180_row19_col9 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_dc180_row19_col10 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# #T_dc180_row19_col12 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_dc180_row20_col8 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_dc180_row20_col9 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_dc180_row20_col10 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_dc180_row20_col11 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_dc180_row20_col12 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_dc180_row21_col9 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_dc180_row21_col10 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_dc180_row21_col11 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_dc180_row21_col12 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_dc180_row22_col9 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_dc180_row22_col11 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_dc180_row23_col9 {
#   background-color: #75c465;
#   color: #000000;
# }
# </style>
# <table id="T_dc180">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc180_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_dc180_level0_col1" class="col_heading level0 col1" >pos</th>
#       <th id="T_dc180_level0_col2" class="col_heading level0 col2" >val</th>
#       <th id="T_dc180_level0_col3" class="col_heading level0 col3" >mins</th>
#       <th id="T_dc180_level0_col4" class="col_heading level0 col4" >pts</th>
#       <th id="T_dc180_level0_col5" class="col_heading level0 col5" >pts-bns</th>
#       <th id="T_dc180_level0_col6" class="col_heading level0 col6" >xp</th>
#       <th id="T_dc180_level0_col7" class="col_heading level0 col7" >ppg</th>
#       <th id="T_dc180_level0_col8" class="col_heading level0 col8" >cs</th>
#       <th id="T_dc180_level0_col9" class="col_heading level0 col9" >gc</th>
#       <th id="T_dc180_level0_col10" class="col_heading level0 col10" >xgc</th>
#       <th id="T_dc180_level0_col11" class="col_heading level0 col11" >xgc90</th>
#       <th id="T_dc180_level0_col12" class="col_heading level0 col12" >saves</th>
#       <th id="T_dc180_level0_col13" class="col_heading level0 col13" >tra_in</th>
#       <th id="T_dc180_level0_col14" class="col_heading level0 col14" >tra_out</th>
#     </tr>
